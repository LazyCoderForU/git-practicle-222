# %%
import pandas as pd  
import numpy as np

# %%
df = pd.read_csv('ner_dataset.csv', encoding = "ISO-8859-1")
df.head(10)
# Out:
#     Sentence #           Word  POS    Tag
# 0  Sentence: 1      Thousands  NNS      O
# 1          NaN             of   IN      O
# 2          NaN  demonstrators  NNS      O
# 3          NaN           have  VBP      O
# 4          NaN        marched  VBN      O
# 5          NaN        through   IN      O
# 6          NaN         London  NNP  B-geo
# 7          NaN             to   TO      O
# 8          NaN        protest   VB      O
# 9          NaN            the   DT      O

# %%
for s in range(1, 11):
    agg = lambda s : [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(),s['POS'].values.tolist(),s['Tag'].values.tolist())]

df.groupby("Sentence #").apply(agg)
# Out:
# C:\Users\pubg3\AppData\Local\Temp\ipykernel_10712\2776930424.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("Sentence #").apply(agg)
# Sentence #
# Sentence: 1         [(thousands, NNS, O)]
# Sentence: 10       [(iranian, JJ, B-gpe)]
# Sentence: 100       [(helicopter, NN, O)]
# Sentence: 1000           [(they, PRP, O)]
# Sentence: 10000      [(u.n., NNP, B-geo)]
#                             ...
# Sentence: 9995     [(opposition, NNP, O)]
# Sentence: 9996              [(on, IN, O)]
# Sentence: 9997      [(following, VBG, O)]
# Sentence: 9998           [(since, IN, O)]
# Sentence: 9999             [(the, DT, O)]
# Length: 47959, dtype: object

# %%
df['Word']
# Out:
# 0              thousands
# 1                     of
# 2          demonstrators
# 3                   have
# 4                marched
#                ...
# 1048570             they
# 1048571        responded
# 1048572               to
# 1048573              the
# 1048574           attack
# Name: Word, Length: 1048575, dtype: object

# %%
a = [(s,w,p,t) for s,w,p,t in df.values[:10]]
a
# Out:
# [('Sentence: 1', 'Thousands', 'NNS', 'O'),
#  (nan, 'of', 'IN', 'O'),
#  (nan, 'demonstrators', 'NNS', 'O'),
#  (nan, 'have', 'VBP', 'O'),
#  (nan, 'marched', 'VBN', 'O'),
#  (nan, 'through', 'IN', 'O'),
#  (nan, 'London', 'NNP', 'B-geo'),
#  (nan, 'to', 'TO', 'O'),
#  (nan, 'protest', 'VB', 'O'),
#  (nan, 'the', 'DT', 'O')]

# %%
df[df.groupby('Sentence #')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df[df.groupby('Sentence #')]
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\indexes\base.py:6195, in Index._get_indexer_strict(self, key, axis_name)
#    6192     keyarr = com.asarray_tuplesafe(keyarr)
#    6194 if self._index_as_unique:
# -> 6195     indexer = self.get_indexer_for(keyarr)
#    6196     keyarr = self.reindex(keyarr)[0]
#    6197 else:
#
# ...

# %%
for (s,w,p,t) in df.values[:100]:
    print(s,w,p,t)
# Out:
# Sentence: 1 Thousands NNS O
# nan of IN O
# nan demonstrators NNS O
# nan have VBP O
# nan marched VBN O
# nan through IN O
# nan London NNP B-geo
# nan to TO O
# nan protest VB O
# nan the DT O
# nan war NN O
# nan in IN O
# nan Iraq NNP B-geo
# nan and CC O
# nan demand VB O
# nan the DT O
# nan withdrawal NN O
# nan of IN O
# nan British JJ B-gpe
# nan troops NNS O
# nan from IN O
# nan that DT O
# nan country NN O
# nan . . O
# Sentence: 2 Families NNS O
# nan of IN O
# nan soldiers NNS O
# nan killed VBN O
# nan in IN O
# nan the DT O
# nan conflict NN O
# nan joined VBD O
# nan the DT O
# nan protesters NNS O
# nan who WP O
# nan carried VBD O
# nan banners NNS O
# nan with IN O
# nan such JJ O
# nan slogans NNS O
# nan as IN O
# nan " `` O
# nan Bush NNP B-per
# nan Number NN O
# nan One CD O
# nan Terrorist NN O
# nan " `` O
# nan and CC O
# nan " `` O
# nan Stop VB O
# nan the DT O
# nan Bombings NNS O
# nan . . O
# nan " `` O
# Sentence: 3 They PRP O
# nan marched VBD O
# ...

# %%
df = pd.read_csv('data.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.groupby('Duration').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
